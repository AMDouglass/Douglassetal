# %%
from pathlib import Path
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_dir = Path('../Data/Table1')

fn_list = {i:item for i, item in enumerate(data_dir.rglob('*')) 
           if (not item.is_dir()) & (item.suffix in ['.pickle','.csv','.txt','.xlsx'])}
fn_list
# Out:
# {1: PosixPath('../Data/Table1/AgRP/062420-3.pickle'),
#  2: PosixPath('../Data/Table1/AgRP/062420-2.pickle')}

# %%
path = fn_list[1]
print(path)

df = pd.read_pickle(path)
                                         
df.plot(x='Time', y='Zscore', ylabel='Z-score', title=path)
df
# Out:
# ../Data/Table1/AgRP/062420-3.pickle
#                 Time    Zscore   Day   ZT
# 0               0.00  0.881236   1.0  0.0
# 1               0.05  0.881254   1.0  0.0
# 2               0.10  0.881273   1.0  0.0
# 3               0.15  0.881295   1.0  0.0
# 4               0.20  0.881320   1.0  0.0
# ...              ...       ...   ...  ...
# 28227698  1412159.80 -0.443925  17.0  8.0
# 28227699  1412159.85 -0.443886  17.0  8.0
# 28227700  1412159.90 -0.443845  17.0  8.0
# 28227701  1412159.95 -0.443801  17.0  8.0
# 28227702  1412160.00 -0.443755  17.0  8.0
#
# [28227703 rows x 4 columns]

# %%
path = fn_list[2]
print(path)

df = pd.read_pickle(path)
                                         
df.plot(x='Time', y='Zscore', ylabel='Z-score', title=path)
df
# Out:
# ../Data/Table1/AgRP/062420-2.pickle
#                 Time    Zscore   Day    ZT
# 0               0.00  0.562126   1.0   0.0
# 1               0.05  0.562213   1.0   0.0
# 2               0.10  0.562301   1.0   0.0
# 3               0.15  0.562391   1.0   0.0
# 4               0.20  0.562484   1.0   0.0
# ...              ...       ...   ...   ...
# 32816365  1641599.80  0.334469  19.0  23.0
# 32816366  1641599.85  0.334492  19.0  23.0
# 32816367  1641599.90  0.334515  19.0  23.0
# 32816368  1641599.95  0.334538  19.0  23.0
# 32816369  1641600.00  0.334558  20.0   0.0
#
# [32816370 rows x 4 columns]
